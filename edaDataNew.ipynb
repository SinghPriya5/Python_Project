# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
edaN=pd.read_csv('data.csv')

# %%
edaN
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
edaN.head().T
# Out:
#                                                        0  \
# Make                                                 BMW
# Model                                         1 Series M
# Year                                                2011
# Engine Fuel Type             premium unleaded (required)
# Engine HP                                          335.0
# Engine Cylinders                                     6.0
# Transmission Type                                 MANUAL
# Driven_Wheels                           rear wheel drive
# Number of Doors                                      2.0
# Market Category    Factory Tuner,Luxury,High-Performance
# Vehicle Size                                     Compact
# Vehicle Style                                      Coupe
# highway MPG                                           26
# city mpg                                              19
# Popularity                                          3916
# ...

# %%
edaN.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
rename_col={'Make':'CarMakerBrand','Year':'Manufacturing_Year', 'Engine Fuel Type':'EngineFuelType', 'Engine HP':'EngineHP',
       'Engine Cylinders':'EngineCylinders', 'Transmission Type':'TransmissionType',
       'Number of Doors':'Number_of_Doors', 'Market Category':'MarketCategory', 'Vehicle Size':'VehicleSize','Vehicle Style':'VehicleStyle',
       'highway MPG':'highwayMPG', 'city mpg':'city_mpg'}

# %%
edaN=edaN.rename(columns=rename_col)

# %%
edaN.head().T
# Out:
#                                                         0  \
# CarMakerBrand                                         BMW
# Model                                          1 Series M
# Manufacturing_Year                                   2011
# EngineFuelType                premium unleaded (required)
# EngineHP                                            335.0
# EngineCylinders                                       6.0
# TransmissionType                                   MANUAL
# Driven_Wheels                            rear wheel drive
# Number_of_Doors                                       2.0
# MarketCategory      Factory Tuner,Luxury,High-Performance
# VehicleSize                                       Compact
# VehicleStyle                                        Coupe
# highwayMPG                                             26
# city_mpg                                               19
# Popularity                                           3916
# ...

# %%
edaN.shape
# Out:
# (11914, 16)

# %%
edaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CarMakerBrand       11914 non-null  object
#  1   Model               11914 non-null  object
#  2   Manufacturing_Year  11914 non-null  int64
#  3   EngineFuelType      11911 non-null  object
#  4   EngineHP            11845 non-null  float64
#  5   EngineCylinders     11884 non-null  float64
#  6   TransmissionType    11914 non-null  object
#  7   Driven_Wheels       11914 non-null  object
#  8   Number_of_Doors     11908 non-null  float64
#  9   MarketCategory      8172 non-null   object
#  10  VehicleSize         11914 non-null  object
#  11  VehicleStyle        11914 non-null  object
#  12  highwayMPG          11914 non-null  int64
#  13  city_mpg            11914 non-null  int64
#  14  Popularity          11914 non-null  int64
# ...

# %%
edaN=edaN.drop_duplicates()

# %%
edaN.shape
# Out:
# (11199, 16)

# %%
edaN.isnull().sum()
# Out:
# CarMakerBrand            0
# Model                    0
# Manufacturing_Year       0
# EngineFuelType           3
# EngineHP                69
# EngineCylinders         30
# TransmissionType         0
# Driven_Wheels            0
# Number_of_Doors          6
# MarketCategory        3376
# VehicleSize              0
# VehicleStyle             0
# highwayMPG               0
# city_mpg                 0
# Popularity               0
# MSRP                     0
# dtype: int64

# %%
edaN['EngineFuelType'].fillna('unkown',inplace=True)
edaN['EngineHP'].fillna(np.median(edaN['EngineHP']),inplace=True)
edaN['EngineCylinders'].fillna(np.median(edaN['EngineCylinders']),inplace=True)
edaN['Number_of_Doors'].fillna(np.median(edaN['Number_of_Doors']),inplace=True)
edaN['MarketCategory'].fillna('unkown',inplace=True)

# %%
edaN[['EngineFuelType','EngineHP','EngineCylinders','Number_of_Doors','MarketCategory']].isnull().sum()
# Out:
# EngineFuelType      0
# EngineHP           69
# EngineCylinders    30
# Number_of_Doors     6
# MarketCategory      0
# dtype: int64

# %%
edaN.sample(10)
# Out:
#       CarMakerBrand          Model  Manufacturing_Year  \
# 7171          Dodge           Neon                2004
# 11399        Suzuki         Vitara                2002
# 3108          Honda      Crosstour                2013
# 6050     Volkswagen   Jetta Hybrid                2014
# 9115         Toyota        Sequoia                2015
# 8446          Buick          Regal                2016
# 10906       Hyundai         Tucson                2015
# 5536       Plymouth  Grand Voyager                1999
# 8530            Kia            Rio                2017
# 2139     Volkswagen         Cabrio                2002
#
#                        EngineFuelType  EngineHP  EngineCylinders  \
# 7171                 regular unleaded     132.0              4.0
# 11399                regular unleaded     127.0              4.0
# 3108                 regular unleaded     278.0              6.0
# 6050      premium unleaded (required)     170.0              4.0
# ...

# %%
edaN['CarMakerBrand'].nunique()
# Out:
# 48

# %%
edaN['Model'].nunique()
# Out:
# 915

# %%
edaN['Manufacturing_Year'].nunique()
# Out:
# 28

# %%
edaN[edaN['Manufacturing_Year']==2017]['MSRP'].nunique()
# Out:
# 1382

# %%
edaN[edaN['MSRP']==edaN['Manufacturing_Year']].head()
# Out:
#      CarMakerBrand    Model  Manufacturing_Year    EngineFuelType  EngineHP  \
# 687          Mazda      626                2000  regular unleaded     130.0
# 2022      Plymouth   Breeze                2000  regular unleaded     132.0
# 2919          Ford  Contour                2000  regular unleaded     170.0
# 4220        Suzuki   Esteem                2000  regular unleaded     122.0
# 4221        Suzuki   Esteem                2000  regular unleaded      95.0
#
#       EngineCylinders TransmissionType      Driven_Wheels  Number_of_Doors  \
# 687               4.0           MANUAL  front wheel drive              4.0
# 2022              4.0           MANUAL  front wheel drive              4.0
# 2919              6.0           MANUAL  front wheel drive              4.0
# 4220              4.0           MANUAL  front wheel drive              4.0
# 4221              4.0           MANUAL  front wheel drive              4.0
#
# ...

# %%
edaN[(edaN['CarMakerBrand']=='BMW') & (edaN['Manufacturing_Year']==2016)].head()
# Out:
#    CarMakerBrand     Model  Manufacturing_Year               EngineFuelType  \
# 41           BMW  2 Series                2016  premium unleaded (required)
# 42           BMW  2 Series                2016  premium unleaded (required)
# 43           BMW  2 Series                2016  premium unleaded (required)
# 44           BMW  2 Series                2016  premium unleaded (required)
# 45           BMW  2 Series                2016  premium unleaded (required)
#
#     EngineHP  EngineCylinders TransmissionType     Driven_Wheels  \
# 41     240.0              4.0        AUTOMATIC  rear wheel drive
# 42     240.0              4.0        AUTOMATIC  rear wheel drive
# 43     320.0              6.0        AUTOMATIC  rear wheel drive
# 44     240.0              4.0        AUTOMATIC   all wheel drive
# 45     240.0              4.0        AUTOMATIC   all wheel drive
#
#     Number_of_Doors                         MarketCategory VehicleSize  \
# ...

# %%
edaN.describe()
# Out:
#        Manufacturing_Year      EngineHP  EngineCylinders  Number_of_Doors  \
# count        11199.000000  11130.000000     11169.000000     11193.000000
# mean          2010.714528    253.388859         5.665950         3.454123
# std              7.228211    110.150938         1.797021         0.872946
# min           1990.000000     55.000000         0.000000         2.000000
# 25%           2007.000000    172.000000         4.000000         2.000000
# 50%           2015.000000    239.000000         6.000000         4.000000
# 75%           2016.000000    303.000000         6.000000         4.000000
# max           2017.000000   1001.000000        16.000000         4.000000
#
#          highwayMPG      city_mpg    Popularity          MSRP
# count  11199.000000  11199.000000  11199.000000  1.119900e+04
# mean      26.610590     19.731851   1558.483347  4.192593e+04
# std        8.977641      9.177555   1445.668872  6.153505e+04
# ...

# %%
sns.boxplot(x=edaN['MSRP'])
plt.show()

# %%
print(edaN['MSRP'].max())
# Out:
# 2065902

# %%
def iqr_technique(DFcolumns):
    Q1=np.percentile(DFcolumns,25)
    Q3=np.percentile(DFcolumns,75)
    IQR=Q3-Q1
    lowerrange=Q1-(1.5*IQR)
    highrange=Q3+(1.5*IQR)
    return lowerrange,highrange

# %%
edaN.head(2)
# Out:
#   CarMakerBrand       Model  Manufacturing_Year               EngineFuelType  \
# 0           BMW  1 Series M                2011  premium unleaded (required)
# 1           BMW    1 Series                2011  premium unleaded (required)
#
#    EngineHP  EngineCylinders TransmissionType     Driven_Wheels  \
# 0     335.0              6.0           MANUAL  rear wheel drive
# 1     300.0              6.0           MANUAL  rear wheel drive
#
#    Number_of_Doors                         MarketCategory VehicleSize  \
# 0              2.0  Factory Tuner,Luxury,High-Performance     Compact
# 1              2.0                     Luxury,Performance     Compact
#
#   VehicleStyle  highwayMPG  city_mpg  Popularity   MSRP
# 0        Coupe          26        19        3916  46135
# 1  Convertible          28        19        3916  40650

# %%
lower_bond,upper_bond=iqr_technique(edaN['MSRP'])
edaN=edaN[(edaN.MSRP>lower_bond) & (edaN.MSRP<upper_bond)]

# %%
sns.boxplot(x=edaN['MSRP'])
plt.show()

# %%
print(edaN['MSRP'].max())
# Out:
# 75010

# %%
sns.boxplot(x=edaN['highwayMPG'])
plt.show()

# %%
lower_bond,upper_bond=iqr_technique(edaN['highwayMPG'])
edaN=edaN[(edaN.highwayMPG>lower_bond) & (edaN.highwayMPG<upper_bond)]

# %%
sns.boxplot(x=edaN['highwayMPG'])
plt.show()

# %%
print(edaN['highwayMPG'].max())
# Out:
# 44

# %%
print(edaN['Popularity'].max())
# Out:
# 5657

# %%
sns.boxplot(x=edaN['Popularity'])
plt.show()

# %%
lower_bond,upper_bond=iqr_technique(edaN['Popularity'])
edaN=edaN[(edaN.Popularity>lower_bond) & (edaN.Popularity<upper_bond)]

# %%
sns.boxplot(x=edaN['Popularity'])
plt.show()

# %%
print(edaN['Popularity'].max())
# Out:
# 3916

# %% [markdown]
# # DataVisualization

# %% [markdown]
# **1.)Distribution of car MSRP range using histrogram**

# %%
plt.figure(figsize=(4,2))
sns.set_theme(style='darkgrid')
sns.displot(edaN['MSRP'],color='purple' ,kde=True)
plt.xlabel('Manufacturers retail price(MSRP)',fontsize=14)
plt.ylabel('Density',fontsize=14)
plt.title('Distribution of car MSRP',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Distribution of car MSRP')

# %% [markdown]
# **Total MSRP count in each manufacturing year using count polt.**

# %%
counts=edaN['Manufacturing_Year'].value_counts()
Top_manufacturing_year_group=counts.reset_index()
Top_manufacturing_year_group.columns=['Manufacturing_Year','MSRP']
Top_manufacturing_year_group
# Out:
#     Manufacturing_Year  MSRP
# 0                 2016  1669
# 1                 2015  1660
# 2                 2017  1326
# 3                 2014   407
# 4                 2007   307
# 5                 2009   301
# 6                 2012   293
# 7                 2008   281
# 8                 2013   268
# 9                 2011   245
# 10                2010   240
# 11                2003   195
# 12                2004   195
# 13                2005   178
# 14                2002   173
# 15                2006   169
# 16                1993   157
# 17                2001   145
# 18                1997   134
# 19                1994   124
# 20                1992   122
# 21                1998   119
# 22                2000   111
# 23                1995   105
# 24                1991   100
# 25                1996    99
# 26                1999    93
# 27                1990    73

# %%
edaN
# Out:
#       CarMakerBrand       Model  Manufacturing_Year  \
# 0               BMW  1 Series M                2011
# 1               BMW    1 Series                2011
# 2               BMW    1 Series                2011
# 3               BMW    1 Series                2011
# 4               BMW    1 Series                2011
# ...             ...         ...                 ...
# 11909         Acura         ZDX                2012
# 11910         Acura         ZDX                2012
# 11911         Acura         ZDX                2012
# 11912         Acura         ZDX                2013
# 11913       Lincoln      Zephyr                2006
#
#                        EngineFuelType  EngineHP  EngineCylinders  \
# 0         premium unleaded (required)     335.0              6.0
# 1         premium unleaded (required)     300.0              6.0
# 2         premium unleaded (required)     300.0              6.0
# 3         premium unleaded (required)     230.0              6.0
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Manufacturing_Year',data=edaN)
plt.title('Total MSRP count ', fontsize=15)
plt.xticks(rotation=90)
plt.xlabel('Manufacturing_Year',fontsize=14)
plt.ylabel('MSRP',fontsize=14)
# Out:
# Text(0, 0.5, 'MSRP')

# %% [markdown]
# **Average MSRP of each manufacuring year using point plot.**

# %%
grouped=edaN.groupby('Manufacturing_Year')['MSRP'].mean()

# %%
manufactureing_year_group_avg_MSRP=grouped.reset_index()

# %%
manufactureing_year_group_avg_MSRP
# Out:
#     Manufacturing_Year          MSRP
# 0                 1990   2034.041096
# 1                 1991   2122.600000
# 2                 1992   2112.786885
# 3                 1993   2249.369427
# 4                 1994   2399.774194
# 5                 1995   2737.533333
# 6                 1996   2627.646465
# 7                 1997   3295.343284
# 8                 1998   3039.100840
# 9                 1999   3053.333333
# 10                2000   3196.315315
# 11                2001  23144.772414
# 12                2002  24469.768786
# 13                2003  24723.415385
# 14                2004  26545.117949
# 15                2005  26941.550562
# 16                2006  27973.372781
# 17                2007  27663.065147
# 18                2008  28796.825623
# 19                2009  31393.730897
# 20                2010  31589.554167
# 21                2011  34740.673469
# 22                2012  32791.675768
# 23                2013  34449.712687
# ...

# %%
manufactureing_year_group_avg_MSRP=manufactureing_year_group_avg_MSRP.rename(columns={'MSRP':'avg_MSRP'})

# %%
manufactureing_year_group_avg_MSRP
# Out:
#     Manufacturing_Year      avg_MSRP
# 0                 1990   2034.041096
# 1                 1991   2122.600000
# 2                 1992   2112.786885
# 3                 1993   2249.369427
# 4                 1994   2399.774194
# 5                 1995   2737.533333
# 6                 1996   2627.646465
# 7                 1997   3295.343284
# 8                 1998   3039.100840
# 9                 1999   3053.333333
# 10                2000   3196.315315
# 11                2001  23144.772414
# 12                2002  24469.768786
# 13                2003  24723.415385
# 14                2004  26545.117949
# 15                2005  26941.550562
# 16                2006  27973.372781
# 17                2007  27663.065147
# 18                2008  28796.825623
# 19                2009  31393.730897
# 20                2010  31589.554167
# 21                2011  34740.673469
# 22                2012  32791.675768
# 23                2013  34449.712687
# ...

# %%
manufactureing_year_group_avg_MSRP['avg_MSRP']=manufactureing_year_group_avg_MSRP['avg_MSRP'].round(2)

# %%
manufactureing_year_group_avg_MSRP
# Out:
#     Manufacturing_Year  avg_MSRP
# 0                 1990   2034.04
# 1                 1991   2122.60
# 2                 1992   2112.79
# 3                 1993   2249.37
# 4                 1994   2399.77
# 5                 1995   2737.53
# 6                 1996   2627.65
# 7                 1997   3295.34
# 8                 1998   3039.10
# 9                 1999   3053.33
# 10                2000   3196.32
# 11                2001  23144.77
# 12                2002  24469.77
# 13                2003  24723.42
# 14                2004  26545.12
# 15                2005  26941.55
# 16                2006  27973.37
# 17                2007  27663.07
# 18                2008  28796.83
# 19                2009  31393.73
# 20                2010  31589.55
# 21                2011  34740.67
# 22                2012  32791.68
# 23                2013  34449.71
# 24                2014  34940.78
# 25                2015  35676.81
# 26                2016  36510.84
# ...

# %%
manufactureing_year_group_avg_MSRP[['Manufacturing_Year','avg_MSRP']].head()
# Out:
#    Manufacturing_Year  avg_MSRP
# 0                1990   2034.04
# 1                1991   2122.60
# 2                1992   2112.79
# 3                1993   2249.37
# 4                1994   2399.77

# %%
plt.figure(figsize=(12,6))
sns.pointplot(x='Manufacturing_Year',y="avg_MSRP",data=manufactureing_year_group_avg_MSRP)
plt.xlabel('Manufacturing Year',fontsize=14)
plt.xticks(rotation=90)
plt.ylabel('Average_MSRP',fontsize=14)
plt.title('Average MSRP By Manufacturing Year')
# Out:
# Text(0.5, 1.0, 'Average MSRP By Manufacturing Year')

# %% [markdown]
# **(4) 	CarMakerBrand Of Each VehicleSize Group using Violin Plot**

# %%
plt.figure(figsize=(12,5))
plt.xticks(rotation=90)
ax= sns.violinplot(x='Driven_Wheels',y='MSRP',data= edaN)

# %% [markdown]
# **4.)Top model by using Bar plot**

# %%
Top_Model=edaN['Model'].value_counts()[:10].reset_index()
Top_Model.columns=['Model','TotalCounts']
Top_Model
# Out:
#              Model  TotalCounts
# 0   Silverado 1500          156
# 1           Tundra          129
# 2      Sierra 1500           90
# 3         Frontier           76
# 4           Accord           74
# 5           Tacoma           71
# 6  Ram Pickup 1500           62
# 7            Civic           62
# 8  C/K 1500 Series           56
# 9         Colorado           54

# %%
Top_Model=edaN['Model'].value_counts()[:10]
colors = ['c', 'g', 'olive', 'y', 'm', 'orange', '#C0C0C0', '#800000', '#008000', '#000080']
Top_Model.plot(kind='bar',color=colors,figsize=(18,7))
plt.xlabel('Top 10 Model',fontsize=14)
plt.ylabel('Total Car Maker Brand Models',fontsize=14)
plt.title('Top 10 Models in Car Maker Brand',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top 10 Models in Car Maker Brand')

# %% [markdown]
# **5.)Top TransmissionType with more sells by using Bar plot**

# %%
Top_TransmissionType=edaN['TransmissionType'].value_counts().reset_index()
Top_TransmissionType.columns=['Top_Transmission_Type','Total_Tansmission']
Top_TransmissionType
# Out:
#   Top_Transmission_Type  Total_Tansmission
# 0             AUTOMATIC               6732
# 1                MANUAL               2225
# 2      AUTOMATED_MANUAL                319
# 3               UNKNOWN                 12
# 4          DIRECT_DRIVE                  1

# %%
Top_TransmissionType=edaN['TransmissionType'].value_counts()
Top_TransmissionType.plot(kind='bar',color='purple',figsize=(8,5))
plt.xlabel('TopTransmissionType',fontsize=14)
plt.xticks(rotation=0)
plt.ylabel('Total Transmission Sells',fontsize=14)
plt.title('Top Transmission Type with more sells on the basis of car maker brand',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top Transmission Type with more sells on the basis of car maker brand')

# %% [markdown]
# **(6) Number Of highway,city mpg for each car maker brand  Using Line Chart**

# %%
No_of_highway=edaN.groupby('CarMakerBrand')['highwayMPG'].count()
#No_of_highway.columns=['CarMakerBrand','highway_count']
type(No_of_highway)
No_of_highway.index
# Out:
# Index(['Acura', 'Alfa Romeo', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'FIAT', 'GMC', 'Genesis', 'HUMMER', 'Honda',
#        'Hyundai', 'Infiniti', 'Kia', 'Land Rover', 'Lexus', 'Lincoln', 'Lotus',
#        'Maserati', 'Mazda', 'Mercedes-Benz', 'Mitsubishi', 'Nissan',
#        'Oldsmobile', 'Plymouth', 'Pontiac', 'Porsche', 'Saab', 'Scion',
#        'Subaru', 'Suzuki', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype='object', name='CarMakerBrand')

# %%
No_of_highway=edaN.groupby('CarMakerBrand')['highwayMPG'].count().reset_index()
locations =No_of_highway.CarMakerBrand
highwayMPG_counts =No_of_highway.highwayMPG
plt.figure(figsize=(15, 5))
plt.plot(locations, highwayMPG_counts, marker='o', ms=12, mew=4, mec='r')
plt.title("Number Of highway for each brand",fontsize=15)
plt.xlabel('Car Maker Brand Name',fontsize=14)
plt.xticks(rotation=90)
plt.ylabel('Number of highway MPG',fontsize=14)
plt.show()

# %%
highwayMPG_counts
# Out:
# 0      241
# 1        5
# 2      271
# 3      226
# 4      190
# 5      314
# 6     1053
# 7      187
# 8      514
# 9       59
# 10     482
# 11       3
# 12      17
# 13     417
# 14     258
# 15     327
# 16     222
# 17      91
# 18     183
# 19     158
# 20      20
# 21       4
# 22     412
# 23     236
# 24     205
# 25     533
# 26     132
# 27      71
# 28     181
# 29      43
# 30     109
# 31      60
# 32     239
# 33     342
# 34     679
# 35     539
# 36     266
# Name: highwayMPG, dtype: int64

# %%
locations
# Out:
# 0             Acura
# 1        Alfa Romeo
# 2              Audi
# 3               BMW
# 4             Buick
# 5          Cadillac
# 6         Chevrolet
# 7          Chrysler
# 8             Dodge
# 9              FIAT
# 10              GMC
# 11          Genesis
# 12           HUMMER
# 13            Honda
# 14          Hyundai
# 15         Infiniti
# 16              Kia
# 17       Land Rover
# 18            Lexus
# 19          Lincoln
# 20            Lotus
# 21         Maserati
# 22            Mazda
# 23    Mercedes-Benz
# 24       Mitsubishi
# 25           Nissan
# 26       Oldsmobile
# 27         Plymouth
# 28          Pontiac
# 29          Porsche
# 30             Saab
# 31            Scion
# 32           Subaru
# 33           Suzuki
# 34           Toyota
# 35       Volkswagen
# 36            Volvo
# Name: CarMakerBrand, dtype: object

# %%
No_of_highway
# Out:
#     CarMakerBrand  highwayMPG
# 0           Acura         241
# 1      Alfa Romeo           5
# 2            Audi         271
# 3             BMW         226
# 4           Buick         190
# 5        Cadillac         314
# 6       Chevrolet        1053
# 7        Chrysler         187
# 8           Dodge         514
# 9            FIAT          59
# 10            GMC         482
# 11        Genesis           3
# 12         HUMMER          17
# 13          Honda         417
# 14        Hyundai         258
# 15       Infiniti         327
# 16            Kia         222
# 17     Land Rover          91
# 18          Lexus         183
# 19        Lincoln         158
# 20          Lotus          20
# 21       Maserati           4
# 22          Mazda         412
# 23  Mercedes-Benz         236
# 24     Mitsubishi         205
# 25         Nissan         533
# 26     Oldsmobile         132
# 27       Plymouth          71
# 28        Pontiac         181
# 29        Porsche          43
# ...

# %% [markdown]
# **(7) Average minimum MSRP in each car maker brand using Scatter and Bar chart**

# %%
minimum_avg_MSRP=edaN.groupby('CarMakerBrand')['MSRP'].mean().reset_index()
minimum_avg_MSRP=minimum_avg_MSRP.rename(columns={'MSRP':'avg_MSRP'})
top_10_min_avg_MSRP=minimum_avg_MSRP.nsmallest(10,'avg_MSRP')
brand_group=edaN['CarMakerBrand'].drop_duplicates()
brand_avg_sorted_with_group=pd.merge(top_10_min_avg_MSRP,brand_group,how='left')
brand_avg_sorted_with_group
# Out:
#   CarMakerBrand      avg_MSRP
# 0      Plymouth   3296.873239
# 1    Oldsmobile  12843.795455
# 2        Suzuki  18026.415205
# 3       Pontiac  19800.044199
# 4         Scion  19932.500000
# 5         Mazda  20416.623786
# 6    Mitsubishi  21316.351220
# 7          FIAT  22206.016949
# 8         Dodge  22626.793774
# 9        Subaru  24240.673640

# %%
#minimum_avg_MSRP=edaN.groupby('CarMakerBrand')['MSRP'].mean()
#CarMakerBrand_MSRP= pd.DataFrame({'CarMakerBrand':minimum_avg_MSRP.index,'avg_MSRP':minimum_avg_MSRP.values})
#df=edaN.merge(CarMakerBrand_MSRP,on='CarMakerBrand')
brand_avg_sorted_with_group.plot.scatter(x="CarMakerBrand", y="avg_MSRP",  title="Average minimum MSRP in each car maker brand ", figsize=(12,6), cmap="plasma")
# Out:
# <Axes: title={'center': 'Average minimum MSRP in each car maker brand '}, xlabel='CarMakerBrand', ylabel='avg_MSRP'>

# %%
brand=brand_avg_sorted_with_group['CarMakerBrand']
MSRP=brand_avg_sorted_with_group['avg_MSRP']

plt.figure(figsize=(15,5))
plt.bar(brand,MSRP,width=0.5, color = 'orchid')
plt.xlabel('Car Maker Brand')
plt.ylabel('Average MCRP')
plt.title('Average MCRP  By CarMakerBrand')

# Show the plot
plt.show()

# %% [markdown]
# **(8) Total Popularity Of each car maker brand **

# %%
Total_Driven_Wheels=edaN['Driven_Wheels'].value_counts().reset_index()
Total_Driven_Wheels.columns=['Driven_Wheels','Total_Counts']
Total_Driven_Wheels
# Out:
#        Driven_Wheels  Total_Counts
# 0  front wheel drive          3996
# 1   rear wheel drive          2340
# 2    all wheel drive          1872
# 3   four wheel drive          1069

# %%
plt.figure(figsize=(12,5))
Total_Driven_Wheels=edaN['Driven_Wheels'].value_counts()
labels=Total_Driven_Wheels.index
sizes=Total_Driven_Wheels.values
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.legend(title='Transmission Type',bbox_to_anchor=(1.5,0,0.5,1), fontsize='13')
plt.show()

# %%
edaN=edaN[edaN['TransmissionType']!='UNKNOWN']

# %%
edaN['TransmissionType'].unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE'],
#       dtype=object)

# %%
Total_TransmissionType=edaN['TransmissionType'].value_counts

# %%
Total_TransmissionType
# Out:
# <bound method IndexOpsMixin.value_counts of 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: TransmissionType, Length: 9277, dtype: object>

# %% [markdown]
# **(9) Requirement car counts by Minimum city_mpg using Bar chart**

# %%
min_city_mpg=edaN.groupby('city_mpg').size()

# %%
min_city_mpg
# Out:
# city_mpg
# 10       7
# 11      81
# 12     147
# 13     359
# 14     414
# 15     694
# 16     883
# 17    1058
# 18     877
# 19     739
# 20     677
# 21     534
# 22     547
# 23     418
# 24     377
# 25     403
# 26     199
# 27     230
# 28     158
# 29      94
# 30     116
# 31     111
# 32      20
# 33      14
# 34      14
# 35      15
# 36      20
# 37       8
# 38       1
# 39       3
# 40      19
# 41      21
# 42       1
# 43       9
# 44       8
# 49       1
# dtype: int64

# %%
min_city_mpg=edaN.groupby('city_mpg').size().reset_index(name='count')
min_city_mpg=min_city_mpg.sort_values('count',ascending=False)
min_city_mpg=min_city_mpg.head(15)
min_city_mpg=min_city_mpg.reset_index(drop=True)
min_city_mpg
# Out:
#     city_mpg  count
# 0         17   1058
# 1         16    883
# 2         18    877
# 3         19    739
# 4         15    694
# 5         20    677
# 6         22    547
# 7         21    534
# 8         23    418
# 9         14    414
# 10        25    403
# 11        24    377
# 12        13    359
# 13        27    230
# 14        26    199

# %%
city_mpg=min_city_mpg['city_mpg']
count=min_city_mpg['count']
plt.figure(figsize=(12, 8))
plt.bar(city_mpg, count)
plt.xlabel('Minimum City MPG',fontsize='14')
plt.ylabel('Count',fontsize='14')
plt.title( 'Requirement car counts by Minimum city_mpg',fontsize=15)
plt.show()

# %% [markdown]
# **(10) Total highwayMPG by each Driven_Wheels in Car maker brand company using Pie Chart**

# %%
highwayMPG_by_each_Car_maker_brand=edaN.groupby('Driven_Wheels')['highwayMPG'].sum()
plt.pie(highwayMPG_by_each_Car_maker_brand,labels=highwayMPG_by_each_Car_maker_brand.index,autopct='%1.1f%%')
plt.title('Total numbers of highway Mpg by each Car brand company',fontsize='15')
plt.show()

# %% [markdown]
# **(11) Number of Max. highwayMPG by each Driven_Wheels in Car maker brand company using Pie Chart**

# %%
highwayMPG_by_each_Car_maker_brand=edaN.groupby('Driven_Wheels')['highwayMPG'].max()
plt.pie(highwayMPG_by_each_Car_maker_brand,labels=highwayMPG_by_each_Car_maker_brand.index,autopct='%1.1f%%')
plt.title('Max. highwayMPG by each Driven_Wheels in Car maker brand company')
plt.show()

# %% [markdown]
# **Correlation Heatmap Visualization**

# %%
edaN.dtypes
# Out:
# CarMakerBrand          object
# Model                  object
# Manufacturing_Year      int64
# EngineFuelType         object
# EngineHP              float64
# EngineCylinders       float64
# TransmissionType       object
# Driven_Wheels          object
# Number_of_Doors       float64
# MarketCategory         object
# VehicleSize            object
# VehicleStyle           object
# highwayMPG              int64
# city_mpg                int64
# Popularity              int64
# MSRP                    int64
# dtype: object

# %%
import copy

# %%
edaN1=copy.deepcopy(edaN)

# %%
edaN1.head(2)
# Out:
#   CarMakerBrand       Model  Manufacturing_Year               EngineFuelType  \
# 0           BMW  1 Series M                2011  premium unleaded (required)
# 1           BMW    1 Series                2011  premium unleaded (required)
#
#    EngineHP  EngineCylinders TransmissionType     Driven_Wheels  \
# 0     335.0              6.0           MANUAL  rear wheel drive
# 1     300.0              6.0           MANUAL  rear wheel drive
#
#    Number_of_Doors                         MarketCategory VehicleSize  \
# 0              2.0  Factory Tuner,Luxury,High-Performance     Compact
# 1              2.0                     Luxury,Performance     Compact
#
#   VehicleStyle  highwayMPG  city_mpg  Popularity   MSRP
# 0        Coupe          26        19        3916  46135
# 1  Convertible          28        19        3916  40650

# %%
edaN1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9277 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CarMakerBrand       9277 non-null   object
#  1   Model               9277 non-null   object
#  2   Manufacturing_Year  9277 non-null   int64
#  3   EngineFuelType      9277 non-null   object
#  4   EngineHP            9262 non-null   float64
#  5   EngineCylinders     9257 non-null   float64
#  6   TransmissionType    9277 non-null   object
#  7   Driven_Wheels       9277 non-null   object
#  8   Number_of_Doors     9277 non-null   float64
#  9   MarketCategory      9277 non-null   object
#  10  VehicleSize         9277 non-null   object
#  11  VehicleStyle        9277 non-null   object
#  12  highwayMPG          9277 non-null   int64
#  13  city_mpg            9277 non-null   int64
#  14  Popularity          9277 non-null   int64
# ...

# %%
column_to_drop=['CarMakerBrand','Model','EngineFuelType','TransmissionType','Driven_Wheels','MarketCategory','VehicleSize','VehicleStyle']

# %%
edaN1.drop(columns=column_to_drop,inplace=True)

# %%
edaN1.head()
# Out:
#    Manufacturing_Year  EngineHP  EngineCylinders  Number_of_Doors  highwayMPG  \
# 0                2011     335.0              6.0              2.0          26
# 1                2011     300.0              6.0              2.0          28
# 2                2011     300.0              6.0              2.0          28
# 3                2011     230.0              6.0              2.0          28
# 4                2011     230.0              6.0              2.0          28
#
#    city_mpg  Popularity   MSRP
# 0        19        3916  46135
# 1        19        3916  40650
# 2        20        3916  36350
# 3        18        3916  29450
# 4        18        3916  34500

# %%
corr=edaN1.corr()

# %%
corr
# Out:
#                     Manufacturing_Year  EngineHP  EngineCylinders  \
# Manufacturing_Year            1.000000  0.371528        -0.073273
# EngineHP                      0.371528  1.000000         0.726047
# EngineCylinders              -0.073273  0.726047         1.000000
# Number_of_Doors               0.272951  0.056304         0.011645
# highwayMPG                    0.346118 -0.453366        -0.694681
# city_mpg                      0.298559 -0.527397        -0.712769
# Popularity                    0.178134  0.101424         0.028457
# MSRP                          0.663405  0.742212         0.360291
#
#                     Number_of_Doors  highwayMPG  city_mpg  Popularity  \
# Manufacturing_Year         0.272951    0.346118  0.298559    0.178134
# EngineHP                   0.056304   -0.453366 -0.527397    0.101424
# EngineCylinders            0.011645   -0.694681 -0.712769    0.028457
# Number_of_Doors            1.000000    0.033209  0.050833   -0.069604
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr,cmap='BrBG',annot=True)
plt.show()

# %% [markdown]
# **Pair Plot Visualization**

# %%
sns.pairplot(edaN1)
plt.show()
